# %% [markdown]
# <a href="https://colab.research.google.com/github/iamakashpatel1/-Machine_Deep_Learning/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

# %%
data = datasets.load_iris()
X = data.data
Y = data.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_pred)
# Out:
# 1.0

# %%
model.intercept_
# Out:
# np.float64(0.21437478551022515)

# %%
model.coef_
# Out:
# array([-0.11774943, -0.05009697,  0.25289541,  0.56316786])

# %%
pd.DataFrame(model.coef_,index=data.feature_names,columns=['coef'])
# Out:
#                        coef
# sepal length (cm) -0.117749
# sepal width (cm)  -0.050097
# petal length (cm)  0.252895
# petal width (cm)   0.563168
